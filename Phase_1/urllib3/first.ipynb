# %%
import urllib3 as url
import requests

# %% [markdown]
# # Pool Manager
# In urllib3 we have to create the poolmanager to handle multiple requests along with thread safety

# %%
http = url.PoolManager()

# %%
r = http.request('GET','https://httpbin.org/robots.txt')
print(r.data)
# Out:
# b'User-agent: *\nDisallow: /deny\n'

# %%
r = http.request('POST','https://httpbin.org/post', fields={'hi':'hello'})
print(r.data)
# Out:
# b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "hi": "hello"\n  }, \n  "headers": {\n    "Accept-Encoding": "identity", \n    "Content-Length": "126", \n    "Content-Type": "multipart/form-data; boundary=115c0c22ae3baa020ad6a367561eb416", \n    "Host": "httpbin.org", \n    "User-Agent": "python-urllib3/2.4.0", \n    "X-Amzn-Trace-Id": "Root=1-687d0927-6c3d734a6c54d1be3a7d9327"\n  }, \n  "json": null, \n  "origin": "139.167.143.182", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'hi': 'hello'},
#  'headers': {'Accept-Encoding': 'identity',
#   'Content-Length': '126',
#   'Content-Type': 'multipart/form-data; boundary=115c0c22ae3baa020ad6a367561eb416',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-urllib3/2.4.0',
#   'X-Amzn-Trace-Id': 'Root=1-687d0927-6c3d734a6c54d1be3a7d9327'},
#  'json': None,
#  'origin': '139.167.143.182',
#  'url': 'https://httpbin.org/post'}

# %%
r.headers
# Out:
# HTTPHeaderDict({'Date': 'Sun, 20 Jul 2025 15:20:07 GMT', 'Content-Type': 'application/json', 'Content-Length': '482', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'})

# %%
import io

# %%
resp = http.request("GET", "https://example.com", preload_content=False)
resp.auto_close = False

for line in io.TextIOWrapper(resp):
    print(line)
# Out:
# <!doctype html>
#
# <html>
#
# <head>
#
#     <title>Example Domain</title>
#
#
#
#     <meta charset="utf-8" />
#
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#
#     <style type="text/css">
#
#     body {
#
#         background-color: #f0f0f2;
#
#         margin: 0;
#
#         padding: 0;
#
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#
#
#     }
#
#     div {
#
#         width: 600px;
#
#         margin: 5em auto;
#
#         padding: 2em;
#
#         background-color: #fdfdff;
#
#         border-radius: 0.5em;
#
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#
#     }
#
#     a:link, a:visited {
#
#         color: #38488f;
#
#         text-decoration: none;
#
#     }
#
#     @media (max-width: 700px) {
#
#         div {
#
#             margin: 0 auto;
#
# ...

# %% [markdown]
# # SENDING FILE USING URLLIB3

# %%
with open('example.txt', 'r') as f:
    file_data = f.read()
    
conn = http.request('POST', 'https://httpbin.org/post', fields={'filefield' : ('example.txt', file_data)})
print(conn.json()['files'])
# Out:
# {'filefield': 'HI\nHELLO\nAASHISH IS GREAT'}

# %%
conn.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {'filefield': 'HI\nHELLO\nAASHISH IS GREAT'},
#  'form': {},
#  'headers': {'Accept-Encoding': 'identity',
#   'Content-Length': '203',
#   'Content-Type': 'multipart/form-data; boundary=c51870afbbb95daa5dc8c25b0cd20f9c',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-urllib3/2.4.0',
#   'X-Amzn-Trace-Id': 'Root=1-687d1382-320bfa802987ad2801afb162'},
#  'json': None,
#  'origin': '62.72.42.240',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# #### For sending raw binary data simply specify the body argument. It’s also recommended to set the Content-Type header

# %%
with open('chrome_2Mp8hrukgX.png', 'rb') as f:
    binary_data = f.read()
    
connection = http.request('POST', 'https://httpbin.org/post', body=binary_data,headers={'Content-Type': 'image/png'})
# Out:
# data:application/octet-stream;base64,...

# %% [markdown]
# ### While streaming using preload_content = False The read_chunk method is used when the content-length in header is not available which means the server isnt sure of how much the data is
